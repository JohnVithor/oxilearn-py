# %%
from safetensors.torch import load_file, save_file

# %%
load_file('/home/johnvithor/Projetos/Rust/oxilearn/safetensors/cart_pole/policy_weights.safetensors')
# Out:
# {'q_net.0.bias': tensor([ 0.0829,  0.0204,  0.0763, -0.2798, -0.4897,  0.0109, -0.2040, -0.1686,
#           0.3681,  0.0817,  0.2284, -0.1397, -0.3967,  0.0997, -0.3311,  0.0620,
#          -0.3902,  0.3769, -0.3406,  0.4341,  0.3532,  0.3780,  0.3000,  0.1157,
#          -0.0244, -0.0080, -0.1989, -0.4596,  0.4557,  0.0259,  0.2352,  0.0184,
#           0.1437, -0.3081, -0.3887,  0.3813,  0.1896,  0.2469, -0.4963,  0.0338,
#          -0.4664, -0.0572, -0.0264, -0.3518, -0.4951,  0.0033,  0.4496,  0.4506,
#          -0.3044, -0.0888, -0.4181, -0.3905, -0.1371,  0.4854, -0.1304,  0.0289,
#           0.4704,  0.0891,  0.4033,  0.3322,  0.4689,  0.0857, -0.4043, -0.4301,
#          -0.2583,  0.4127,  0.2875,  0.1463, -0.3808, -0.3683,  0.4079, -0.0519,
#          -0.4978, -0.0618, -0.1200,  0.0075,  0.2093,  0.1924, -0.3826, -0.0055,
#          -0.2478,  0.3382,  0.2476,  0.2744,  0.4546,  0.2456, -0.4996,  0.1262,
# ...

# %%
load_file('/home/johnvithor/Projetos/Rust/oxilearn/safetensors-python/cart_pole/policy_weights.safetensors')
# Out:
# {'0.bias': tensor([ 0.0829,  0.0204,  0.0763, -0.2798, -0.4897,  0.0109, -0.2040, -0.1686,
#           0.3681,  0.0817,  0.2284, -0.1397, -0.3967,  0.0997, -0.3311,  0.0620,
#          -0.3902,  0.3769, -0.3406,  0.4341,  0.3532,  0.3780,  0.3000,  0.1157,
#          -0.0244, -0.0080, -0.1989, -0.4596,  0.4557,  0.0259,  0.2352,  0.0184,
#           0.1437, -0.3081, -0.3887,  0.3813,  0.1896,  0.2469, -0.4963,  0.0338,
#          -0.4664, -0.0572, -0.0264, -0.3518, -0.4951,  0.0033,  0.4496,  0.4506,
#          -0.3044, -0.0888, -0.4181, -0.3905, -0.1371,  0.4854, -0.1304,  0.0289,
#           0.4704,  0.0891,  0.4033,  0.3322,  0.4689,  0.0857, -0.4043, -0.4301,
#          -0.2583,  0.4127,  0.2875,  0.1463, -0.3808, -0.3683,  0.4079, -0.0519,
#          -0.4978, -0.0618, -0.1200,  0.0075,  0.2093,  0.1924, -0.3826, -0.0055,
#          -0.2478,  0.3382,  0.2476,  0.2744,  0.4546,  0.2456, -0.4996,  0.1262,
# ...

# %%
2.3e-3
# Out:
# 0.0023
